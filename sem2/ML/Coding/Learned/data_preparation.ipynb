# %% [markdown]
# ![data_preparation.png](attachment:data_preparation.png)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows',10,'display.max_columns',10)#to limit how many columns and rows would like to see if not used then put NONE

# %%
flights = pd.read_csv('sampled_flights.csv')
flights.shape
# Out:
# (100, 31)

# %%
flights#set_option limits the visible rows and columns
# Out:
#     YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  ...  AIR_SYSTEM_DELAY  \
# 0   2015      1    1            4      AS  ...               NaN
# 1   2015      1    1            4      AA  ...               NaN
# 2   2015      1    1            4      US  ...               NaN
# 3   2015      1    1            4      AA  ...               NaN
# 4   2015      1    1            4      AS  ...               NaN
# ..   ...    ...  ...          ...     ...  ...               ...
# 95  2015      1    1            4      B6  ...               NaN
# 96  2015      1    1            4      B6  ...               NaN
# 97  2015      1    1            4      B6  ...               0.0
# 98  2015      1    1            4      EV  ...               NaN
# 99  2015      1    1            4      EV  ...               NaN
#
#    SECURITY_DELAY AIRLINE_DELAY LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN           NaN                 NaN            NaN
# ...

# %%
flights.head()#1st 5 rows will be visible
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  ...  AIR_SYSTEM_DELAY  \
# 0  2015      1    1            4      AS  ...               NaN
# 1  2015      1    1            4      AA  ...               NaN
# 2  2015      1    1            4      US  ...               NaN
# 3  2015      1    1            4      AA  ...               NaN
# 4  2015      1    1            4      AS  ...               NaN
#
#   SECURITY_DELAY AIRLINE_DELAY LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0            NaN           NaN                 NaN            NaN
# 1            NaN           NaN                 NaN            NaN
# 2            NaN           NaN                 NaN            NaN
# 3            NaN           NaN                 NaN            NaN
# 4            NaN           NaN                 NaN            NaN
#
# [5 rows x 31 columns]

# %%
flights.head(8)#1st 5 rows will be visible
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  ...  AIR_SYSTEM_DELAY  \
# 0  2015      1    1            4      AS  ...               NaN
# 1  2015      1    1            4      AA  ...               NaN
# 2  2015      1    1            4      US  ...               NaN
# 3  2015      1    1            4      AA  ...               NaN
# 4  2015      1    1            4      AS  ...               NaN
# 5  2015      1    1            4      DL  ...               NaN
# 6  2015      1    1            4      NK  ...               NaN
# 7  2015      1    1            4      US  ...               NaN
#
#   SECURITY_DELAY AIRLINE_DELAY LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0            NaN           NaN                 NaN            NaN
# 1            NaN           NaN                 NaN            NaN
# 2            NaN           NaN                 NaN            NaN
# 3            NaN           NaN                 NaN            NaN
# ...
